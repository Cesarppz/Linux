# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# <frozen importlib._bootstrap>:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
# <frozen importlib._bootstrap>:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
# <frozen importlib._bootstrap>:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject

# %%
df = pd.read_csv('iris-data.csv')
df.columns
# Out:
# Index(['Unnamed: 0', 'lar.sepalo', 'anc.sepalo', 'lar.petalo', 'anc.petalo',
#        'tipo_flor'],
#       dtype='object')

# %%
df['tipo_flor'].value_counts()
# Out:
# 2.0    50
# 1.0    50
# 0.0    50
# Name: tipo_flor, dtype: int64

# %%
plt.figure(figsize=(10,5))
plt.hist(df['lar.petalo'],bins=30,label='largo petalo')
plt.axvline(np.mean(df['lar.petalo']),label='Media $\mu$',linestyle='--',c='k')
plt.axvline(np.mean(df['lar.petalo']) + np.std(df['lar.petalo']),label='$\mu + \sigma$',linestyle='--',c='r')
plt.legend()
plt.show()

# %% [markdown]
# Para estandarizar esta distribución debemos aplizar la formula de $Z$
# $$Z = \frac{x-\mu}{\sigma} $$
# Donde la distribución pasa a tner parametros adimencionales

# %%
x = df['lar.petalo']
z = (x - np.mean(x)) / np.std(x)
mu_z = np.mean(z)
std_z = np.std(z)

# %%
plt.figure(figsize=(10,5))
plt.hist(z,bins=30,label='largo petalo')
plt.axvline(mu_z,label='Media estandarizada $\mu$',linestyle='--',c='k')
plt.axvline(mu_z + std_z,label='$\mu + \sigma$',linestyle='--',c='r')
plt.legend(fontsize='large')
plt.show()

# %% [markdown]
# # Covarianza
# <ul>
#     <li>Mide la dirección (signo) de la relación de las variables</li>
#     <li>No mide la magnitud</li>
#     <li>Rango $Cov(X) = [-∞,∞ ]$</li>
# </ul>

# %%
#Esto me entrga una matriz donde los valores de la covarianza son los que se repiten, y estan baja a la izquiera y arriba a la derecha
np.cov(df['lar.petalo'],df['lar.sepalo'])
# Out:
# array([[3.11627785, 1.27431544],
#        [1.27431544, 0.68569351]])

# %% [markdown]
# $$\begin{bmatrix}
#    varianza_a & Cov \\
#    Cov & varianza_b
# \end{bmatrix}$$

# %% [markdown]
# # Correlación
# <ul>
#     <li>Mide la dirección (signo) de la relación de las variables</li>
#     <li>Mide la magnitud</li>
#     <li>Rango $Cov(X) = [-1,1 ]$</li>
#     <li>Relación lineal perfecta: 1 o -1</li>
# </ul>

# %%
plt.scatter(df['lar.petalo'],df['lar.sepalo'],alpha=0.5)
plt.autoscale()

# %% [markdown]
# Correlación Kendall

# %%
corrK = df.corr(method = 'kendall')  #No mide necesariamente variables lineales
corrK
# Out:
#             Unnamed: 0  lar.sepalo  anc.sepalo  lar.petalo  anc.petalo  \
# Unnamed: 0    1.000000    0.525219   -0.273798    0.643863    0.681672
# lar.sepalo    0.525219    1.000000   -0.076997    0.718516    0.655309
# anc.sepalo   -0.273798   -0.076997    1.000000   -0.185994   -0.157126
# lar.petalo    0.643863    0.718516   -0.185994    1.000000    0.806891
# anc.petalo    0.681672    0.655309   -0.157126    0.806891    1.000000
# tipo_flor     0.819232    0.670444   -0.337614    0.822911    0.839687
#
#             tipo_flor
# Unnamed: 0   0.819232
# lar.sepalo   0.670444
# anc.sepalo  -0.337614
# lar.petalo   0.822911
# anc.petalo   0.839687
# tipo_flor    1.000000

# %% [markdown]
# Correlación Pearson

# %%
corrP = df.corr(method = 'pearson')
corrP
# Out:
#             Unnamed: 0  lar.sepalo  anc.sepalo  lar.petalo  anc.petalo  \
# Unnamed: 0    1.000000    0.716676   -0.402301    0.882637    0.900027
# lar.sepalo    0.716676    1.000000   -0.117570    0.871754    0.817941
# anc.sepalo   -0.402301   -0.117570    1.000000   -0.428440   -0.366126
# lar.petalo    0.882637    0.871754   -0.428440    1.000000    0.962865
# anc.petalo    0.900027    0.817941   -0.366126    0.962865    1.000000
# tipo_flor     0.942830    0.782561   -0.426658    0.949035    0.956547
#
#             tipo_flor
# Unnamed: 0   0.942830
# lar.sepalo   0.782561
# anc.sepalo  -0.426658
# lar.petalo   0.949035
# anc.petalo   0.956547
# tipo_flor    1.000000

# %% [markdown]
# Correlación Spearman
#
# Es la típica

# %%
corr = df.corr(method='spearman')
corr
# Out:
#             Unnamed: 0  lar.sepalo  anc.sepalo  lar.petalo  anc.petalo  \
# Unnamed: 0    1.000000    0.734054   -0.415147    0.867812    0.879963
# lar.sepalo    0.734054    1.000000   -0.166778    0.881898    0.834289
# anc.sepalo   -0.415147   -0.166778    1.000000   -0.309635   -0.289032
# lar.petalo    0.867812    0.881898   -0.309635    1.000000    0.937667
# anc.petalo    0.879963    0.834289   -0.289032    0.937667    1.000000
# tipo_flor     0.942830    0.798078   -0.440290    0.935431    0.938179
#
#             tipo_flor
# Unnamed: 0   0.942830
# lar.sepalo   0.798078
# anc.sepalo  -0.440290
# lar.petalo   0.935431
# anc.petalo   0.938179
# tipo_flor    1.000000

# %%
df.columns

# %%
plt.figure(figsize=(10,5))
sns.heatmap(corr, xticklabels=df.columns,yticklabels=df.columns,cmap='Spectral',annot=True)
plt.show()

# %%
mask = np.zeros_like(corr, dtype = np.bool)
mask[np.triu_indices(len(corr),1)] = True
sns.heatmap(corr, xticklabels=df.columns,yticklabels=df.columns,mask=mask )
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df.corr()[['tipo_flor']].sort_values(by=['tipo_flor'],ascending=False),cmap='Spectral',annot=True)
plt.show()
